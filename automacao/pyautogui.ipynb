# %% [markdown]
# # Como usar Python para automação?

# %%
import pyautogui as pag
from time import sleep

# %% [markdown]
# Como pegar o tamanho da tela?

# %%
print(pag.size())
# Out:
# Size(width=1360, height=768)

# %% [markdown]
# Como pegar a posição?

# %%
sleep(2)
x, y = pag.position()
print(pag.position())
print(x)
# Out:
# Point(x=455, y=340)
# 455

# %% [markdown]
# Se o cursor está em um pixel?

# %%
print(pag.onScreen(x, y))
# Out:
# True

# %% [markdown]
# Como movimentar o mouse?

# %%
pag.moveTo(0,0, 2)

# %% [markdown]
# Como segurar e mover o mouse?

# %%
# pag.dragTo(1,1, button='left', duration=4)
# Esperimente com um arquivo na area de trabalho

# %% [markdown]
# Como clicar?

# %%
# pag.click(100, 10, clicks=1)
# pag.doubleClick()

# %% [markdown]
# Como usar o scroll?

# %%
pag.scroll(300)

# %% [markdown]
# Teclado

# %%
sleep(2)
pag.write("Hello!")

# %% [markdown]
# Como usar os atalho?

# %%
pag.hotkey("ctrl", "c")
